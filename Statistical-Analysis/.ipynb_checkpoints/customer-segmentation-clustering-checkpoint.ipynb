# %%
import pandas as pd
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Administrator.LINDO\Desktop\customer_rfm_data.csv')

# %%
features = df[['recency', 'frequency', 'monetary']]

# %%
features = features.fillna(0)

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df['risk_cluster'] = kmeans.fit_predict(scaled_features)

# %%
cluster_summary = df.groupby('risk_cluster')[['recency', 'frequency', 'monetary']].mean()

# %%
cluster_summary
# Out:
#               recency  frequency  monetary
# risk_cluster
# 0                 0.0   2.000000   788.300
# 1                 3.2   0.714286   900.132
# 2                 5.0   2.000000  2300.610
